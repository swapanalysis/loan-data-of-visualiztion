# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Downloads'

# %%
import pandas as pd

# %%
x=pd.read_csv("loan_data_set.csv")

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x=pd.read_csv("loan_data_set.csv",header=1)

# %%
x
# Out:
#      LP001002    Male   No   0      Graduate No.1  5849     0.1  Unnamed: 8  \
# 0    LP001003    Male  Yes   1      Graduate   No  4583  1508.0       128.0
# 1    LP001005    Male  Yes   0      Graduate  Yes  3000     0.0        66.0
# 2    LP001006    Male  Yes   0  Not Graduate   No  2583  2358.0       120.0
# 3    LP001008    Male   No   0      Graduate   No  6000     0.0       141.0
# 4    LP001011    Male  Yes   2      Graduate  Yes  5417  4196.0       267.0
# ..        ...     ...  ...  ..           ...  ...   ...     ...         ...
# 608  LP002978  Female   No   0      Graduate   No  2900     0.0        71.0
# 609  LP002979    Male  Yes  3+      Graduate   No  4106     0.0        40.0
# 610  LP002983    Male  Yes   1      Graduate   No  8072   240.0       253.0
# 611  LP002984    Male  Yes   2      Graduate   No  7583     0.0       187.0
# 612  LP002990  Female   No   0      Graduate  Yes  4583     0.0       133.0
#
#        360    1      Urban  Y
# ...

# %%
x=pd.read_csv("loan_data_set.csv",index_col=[0,1])

# %%
x
# Out:
#                 Married Dependents     Education Self_Employed  \
# Loan_ID  Gender
# LP001002 Male        No          0      Graduate            No
# LP001003 Male       Yes          1      Graduate            No
# LP001005 Male       Yes          0      Graduate           Yes
# LP001006 Male       Yes          0  Not Graduate            No
# LP001008 Male        No          0      Graduate            No
# ...                 ...        ...           ...           ...
# LP002978 Female      No          0      Graduate            No
# LP002979 Male       Yes         3+      Graduate            No
# LP002983 Male       Yes          1      Graduate            No
# LP002984 Male       Yes          2      Graduate            No
# LP002990 Female      No          0      Graduate           Yes
#
#                  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Loan_ID  Gender
# LP001002 Male               5849                0.0         NaN
# ...

# %%
x=pd.read_csv("loan_data_set.csv",index_col=["Credit_History"])

# %%
x
# Out:
#                  Loan_ID  Gender Married Dependents     Education  \
# Credit_History
# 1.0             LP001002    Male      No          0      Graduate
# 1.0             LP001003    Male     Yes          1      Graduate
# 1.0             LP001005    Male     Yes          0      Graduate
# 1.0             LP001006    Male     Yes          0  Not Graduate
# 1.0             LP001008    Male      No          0      Graduate
# ...                  ...     ...     ...        ...           ...
# 1.0             LP002978  Female      No          0      Graduate
# 1.0             LP002979    Male     Yes         3+      Graduate
# 1.0             LP002983    Male     Yes          1      Graduate
# 1.0             LP002984    Male     Yes          2      Graduate
# 0.0             LP002990  Female      No          0      Graduate
#
#                Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Credit_History
# ...

# %%
x=pd.read_csv("loan_data_set.csv",nrows=2)

# %%
x
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No           0  Graduate            No
# 1  LP001003   Male     Yes           1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         NaN               360
# 1             4583               1508       128.0               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N

# %%
x=pd.read_csv("loan_data_set.csv")

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
x.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
x.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
x.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
x.shape
# Out:
# (614, 13)

# %%
x.mean()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7820/3791599204.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.mean()
# ApplicantIncome      5403.459283
# CoapplicantIncome    1621.245798
# LoanAmount            146.412162
# Loan_Amount_Term      342.000000
# Credit_History          0.842199
# dtype: float64

# %%
x.median()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7820/2012539586.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.median()
# ApplicantIncome      3812.5
# CoapplicantIncome    1188.5
# LoanAmount            128.0
# Loan_Amount_Term      360.0
# Credit_History          1.0
# dtype: float64

# %%
x.min()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7820/2461629790.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.min()
# Loan_ID              LP001002
# Education            Graduate
# ApplicantIncome           150
# CoapplicantIncome         0.0
# LoanAmount                9.0
# Loan_Amount_Term         12.0
# Credit_History            0.0
# Property_Area           Rural
# Loan_Status                 N
# dtype: object

# %%
x.max()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7820/557561640.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.max()
# Loan_ID                  LP002990
# Education            Not Graduate
# ApplicantIncome             81000
# CoapplicantIncome         41667.0
# LoanAmount                  700.0
# Loan_Amount_Term            480.0
# Credit_History                1.0
# Property_Area               Urban
# Loan_Status                     Y
# dtype: object

# %%
x.std()
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7820/2178744708.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.std()
# ApplicantIncome      6109.041673
# CoapplicantIncome    2926.248369
# LoanAmount             85.587325
# Loan_Amount_Term       65.120410
# Credit_History          0.364878
# dtype: float64

# %%
x.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
x.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
x.describe(include=["object"])
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
x.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
x["Loan_ID"].nunique()
# Out:
# 614

# %%
x["Married"].nunique()
# Out:
# 2

# %%
x["Loan_Status"].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
x["Married"].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
x["Loan_Status"].value_counts(normalize=True)*100
# Out:
# Y    68.729642
# N    31.270358
# Name: Loan_Status, dtype: float64

# %%
x["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
x["Loan_Status"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Loan_Status'>

# %%
x["LoanAmount"].max()
# Out:
# 700.0

# %%
x["LoanAmount"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x["LoanAmount"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
x["LoanAmount"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pd.crosstab(x["Gender"],x["Loan_Status"],margins=True)
# Out:
# Loan_Status    N    Y  All
# Gender
# Female        37   75  112
# Male         150  339  489
# All          187  414  601

# %%
pd.crosstab(x["Gender"],x["Loan_Status"],normalize="index")*100
# Out:
# Loan_Status          N          Y
# Gender
# Female       33.035714  66.964286
# Male         30.674847  69.325153

# %%
pd.crosstab(x["Gender"],x["Loan_Status"],normalize="columns")*100
# Out:
# Loan_Status          N          Y
# Gender
# Female       19.786096  18.115942
# Male         80.213904  81.884058

# %%
pd.crosstab(x["Gender"],x["Loan_Status"],normalize="index").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(x["Credit_History"],x["Loan_Status"],normalize="index").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
x["aplicant_inr"]=x["ApplicantIncome"]*83

# %%
y=x.corr()

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x["aplicant_inr"]=x["ApplicantIncome"]*83

# %%
y=x.corr()

# %%
x.info
# Out:
# <bound method DataFrame.info of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x.isnull
# Out:
# <bound method DataFrame.isnull of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# aplicant_inr          0
# dtype: int64

# %%
x["LoanAmount"].median()
# Out:
# 128.0

# %%
x["LoanAmount"]=x["LoanAmount"].fillna(x["LoanAmount"].median())

# %%
x.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# aplicant_inr          0
# dtype: int64

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x["LoanAmount"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
