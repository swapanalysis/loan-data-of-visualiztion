# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Downloads'

# %%
import pandas as pd

# %%
y=pd.read_csv("loan_data_set.csv")

# %%
y
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 plt.figure(figsize=(1000,1000))
    
 sns.catplot(data=y,x="Loan_Status",kind="count")

# %%
sns.displot(x["LoanAmount"])
plt.figure(figsize=(10,7))

# %%
sns.joinplot(data=y,x="ApplicantIncome",y="LoanAmount",kind="scatter")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2292/4228730747.py in <module>
# ----> 1 sns.joinplot(data=y,x="ApplicantIncome",y="LoanAmount",kind="scatter")
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
y
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.joinplot(data=y,x="ApplicantIncome",y="LoanAmount",kind="scatter")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2292/675619273.py in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.joinplot(data=y,x="ApplicantIncome",y="LoanAmount",kind="scatter")
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
sns.pairplot(data=y)

# %%
sns.catplot(data=y,x="Gender",y="LoanAmount",kind="box",hue="Loan_Status")

# %%
sns.catplot(data=y,x="Gender",y="LoanAmount",kind="violin")

# %%
sns.catplot(data=y,x="Gender",y="LoanAmount",kind="swarm")
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
